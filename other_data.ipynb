# %%
import pandas as pd
import numpy as np
import pandas_profiling

from datetime import datetime, timedelta

# %% [markdown]
# # Functions

# %%
data_path = './data/'

def read_data(fn):
    df = pd.read_csv(data_path+fn)
    print(df.head())
    return df

def save_tables(df, fn):
    df.to_csv(data_path+fn, index=False)

# %% [markdown]
# # View data

# %%
# !ls data/
# Out:
# agenteSalas_cantidad_salas.csv	Software SalasISyC.xlsx
# agenteSalas_equipos.csv		SoftwareSalasUniandes.docx
# agenteSalas_historial.csv	software_turing.csv
# ips_salas.txt			software_waira.csv
# ISIS_cantidad_salas.csv		tabla_equipo.csv
# ISIS_equipos.csv		tabla_fact.csv
# ISIS_equipos.csv.xlsx		tabla_fecha.csv
# ISIS_historial.csv		tabla_sala.csv
# ISIS_historial.csv.xlsx		tabla_usuario.csv
# reservas.csv			table_fact_zeros.csv
# Reservas Salas.xlsx

# %%
df_reservas = read_data('reservas.csv')
# Out:
#               ESTADO            FECHA FIN         FECHA INICIO  \
# 0  Reserva Cancelada  2016-01-12 15:30:00  2016-01-12 14:00:00
# 1   Reserva Cumplida  2016-01-13 11:00:00  2016-01-13 10:00:00
# 2   Reserva Cumplida  2016-01-13 12:30:00  2016-01-13 11:00:00
# 3   Reserva Cumplida  2016-01-13 15:30:00  2016-01-13 14:00:00
# 4   Reserva Cumplida  2016-01-14 14:00:00  2016-01-14 13:00:00
#
#          FECHA RESERVA                                             MOTIVO  \
# 0  2016-01-12 00:00:00                                     Reunión Websis
# 1  2016-01-13 00:00:00  Reunión ISIS-1001 introducción a ingeniería de...
# 2  2016-01-13 00:00:00                                  Marilyn Rodriguez
# 3  2016-01-13 00:00:00                                 Reunión CupiTaller
# 4  2016-01-14 00:00:00          Inducción Estudiantes de Primer Semestre.
#
#     RESPONSABLE                   SALA
# 0      da-moren  Sala de Juntas ML 768
# 1         crozo  Sala de Juntas ML 768
# ...

# %%
df_sw_turing = read_data('software_turing.csv')
# Out:
#                                      Programa version 2010-10 versión 2012-10  \
# 0                                       7-Zip       9.20.00.0             9.2
# 1                                  ActivePerl       5.12.1202     5.14.2.1402
# 2                           Agente monitoreo      10.1.102.64      11.0.1.152
# 3  Adobe Flash Player Plugin  (2 navegadores)          10.0.0          10.1.1
# 4                                Adobe Reader             NaN             NaN
#
#   versión 2013-10 versión 2015-10 versión 2016-10 versión 2016-20  \
# 0             9.2       9.20.00.0           16.02           16.02
# 1     5.16.1.1601       5.20.2000            5.24            5.24
# 2    11.5.502.110            16.0      19.0.0.185      19.0.0.185
# 3            11.0            11.0          15.017          15.017
# 4       5.4.30920            11.0            11.0           15017
#
#   versión 2017-20
# 0           16.02
# 1            5.24
# 2      19.0.0.185
# 3          15.017
# ...

# %%
df_sw_waira = read_data('software_waira.csv')
# Out:
#                                     Programa versión 2011-10 inicial  \
# 0                                      7-Zip               9.20.00.0
# 1                                 ActivePerl               5.12.1202
# 2              Adobe Flash Player 10 ActiveX                     NaN
# 3  Adobe Flash Player Plugin (2 navegadores)             10.1.102.64
# 4                               Adobe Reader                  10.0.0
#
#   versión 2011-10 final versión 2011-20 inicial versión 2011-20 final  \
# 0             9.20.00.0               9.20.00.0             9.20.00.0
# 1             5.12.1202             5.14.1.1401                  5.12
# 2                   NaN                     NaN           10.1.102.64
# 3           10.1.102.64             10.3.181.34           10.1.102.64
# 4                10.0.0                    10.1                  10.1
#
#   versión 2012-10 versión 2012-20 versión 2013-10 versión 2015-10  \
# ...

# %%
df_sw_turing.head()
# Out:
#                                      Programa version 2010-10 versión 2012-10  \
# 0                                       7-Zip       9.20.00.0             9.2
# 1                                  ActivePerl       5.12.1202     5.14.2.1402
# 2                           Agente monitoreo      10.1.102.64      11.0.1.152
# 3  Adobe Flash Player Plugin  (2 navegadores)          10.0.0          10.1.1
# 4                                Adobe Reader             NaN             NaN
#
#   versión 2013-10 versión 2015-10 versión 2016-10 versión 2016-20  \
# 0             9.2       9.20.00.0           16.02           16.02
# 1     5.16.1.1601       5.20.2000            5.24            5.24
# 2    11.5.502.110            16.0      19.0.0.185      19.0.0.185
# 3            11.0            11.0          15.017          15.017
# 4       5.4.30920            11.0            11.0           15017
#
#   versión 2017-20
# 0           16.02
# 1            5.24
# 2      19.0.0.185
# 3          15.017
# ...

# %% [markdown]
# # Reservas

# %%
pandas_profiling.ProfileReport(df_reservas)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# # Software

# %%
pandas_profiling.ProfileReport(df_sw_turing)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
pandas_profiling.ProfileReport(df_sw_waira)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
